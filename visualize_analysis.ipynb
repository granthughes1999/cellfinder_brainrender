# %%
import pandas as pd
import numpy as np
import UpdateME 
from UpdateME import cellfinder_output_path

# %%
mouse_id = 'test_000'
cellfinder_output_path = '/Users/grant/Desktop/cellfinder_gfp_wholebrain_030723_33/'

# %%
# Path to cellfinder_output points.npy file
cells_path = cellfinder_output_path + 'points/points.npy'
cells_path
points = np.load(cells_path)
print(np.shape(points))
# Out:
# (6656, 3)

# %% [markdown]
# ### if you want to visualize data from a different mouse
# #### update the cellfinder_output_path and mouse_id variables in the variables.py file in this repository

# %%
# import cellfinder inital data
gfp_df = pd.read_csv(cellfinder_output_path + 'analysis/' + 'gfp_summary.csv')
# summary_df_0 = pd.read_csv(cellfinder_output_path + 'analysis/' + 'summary.csv')
tdTomato_df = pd.read_csv(cellfinder_output_path + 'analysis/' + 'tdTomato_summary.csv')

# import analyized data
# labled_cells_df = pd.read_csv(cellfinder_output_path + mouse_id +'_Completed_Analysis/' + mouse_id + '_labled_cells.csv')
# summary_df = pd.read_csv(cellfinder_output_path + mouse_id + '_Completed_Analysis/'+ mouse_id + '_summary_df.csv')

# %% [markdown]
# # Compare GFP to tdTomato labled cells
# #### This was organized using the brain regions containing the most gfp cells in row 1

# %%
print('You are currently looking at the following cellfinder output folder, and evaluating the following mouse_id')
print('')
print(cellfinder_output_path)

print('')
print(mouse_id)
# Out:
# You are currently looking at the following cellfinder output folder, and evaluating the following mouse_id
#
# /Users/grant/Desktop/cellfinder_gf_wholebrain_030723_33/
#
# test_000

# %%
gfp_df.head(20)
# Out:
#                                        structure_name  left_cell_count  \
# 0                                 Main olfactory bulb            105.0
# 1            Retrosplenial area, dorsal part, layer 5             48.0
# 2          Retrosplenial area, dorsal part, layer 2/3             39.0
# 3                      Primary visual area, layer 2/3             32.0
# 4        olfactory nerve layer of main olfactory bulb             41.0
# 5   Retrosplenial area, lateral agranular part, la...             21.0
# 6           Retrosplenial area, ventral part, layer 5             27.0
# 7                       Secondary motor area, layer 5             39.0
# 8   Retrosplenial area, lateral agranular part, la...             30.0
# 9                        Primary visual area, layer 5             23.0
# 10        Retrosplenial area, ventral part, layer 2/3             10.0
# 11                    Secondary motor area, layer 2/3             30.0
# 12                       Primary visual area, layer 4             17.0
# 13                           Visceral area, layer 2/3              2.0
# 14                                         Uvula (IX)             47.0
# 15      Spinal nucleus of the trigeminal, caudal part             13.0
# 16                                    Olfactory areas             22.0
# 17                        Primary motor area, Layer 5             31.0
# 18          Retrosplenial area, ventral part, layer 1              9.0
# 19                                     choroid plexus             35.0
#
#     right_cell_count  total_cells  left_volume_mm3  right_volume_mm3  \
# 0              140.0        245.0         7.999125          8.035750
# 1              164.0        212.0         0.644750          0.626500
# 2              148.0        187.0         0.515875          0.511125
# 3              124.0        156.0         1.117625          1.094000
# 4              108.0        149.0         1.978500          2.041000
# 5              104.0        125.0         0.366750          0.353875
# 6               93.0        120.0         0.890625          0.854000
# 7               79.0        118.0         2.285000          2.316000
# 8               84.0        114.0         0.400125          0.388375
# 9               86.0        109.0         0.868750          0.855750
# 10              92.0        102.0         0.551875          0.539750
# 11              65.0         95.0         1.827250          1.871625
# 12              63.0         80.0         0.567500          0.562875
# 13              68.0         70.0         0.291375          0.281875
# 14              22.0         69.0         0.977125          1.022875
# 15              51.0         64.0         0.798500          0.798750
# 16              39.0         61.0         2.497250          2.588375
# 17              28.0         59.0         1.645875          1.632375
# 18              47.0         56.0         0.429625          0.537375
# 19              20.0         55.0         0.685875          0.733250
#
#     total_volume_mm3  left_cells_per_mm3  right_cells_per_mm3
# 0          16.034875           13.126436            17.422145
# 1           1.271250           74.447460           261.771748
# 2           1.027000           75.599709           289.557349
# 3           2.211625           28.632144           113.345521
# 4           4.019500           20.722770            52.915238
# 5           0.720625           57.259714           293.889085
# 6           1.744625           30.315789           108.899297
# 7           4.601000           17.067834            34.110535
# 8           0.788500           74.976570           216.285806
# 9           1.724500           26.474820           100.496640
# 10          1.091625           18.120045           170.449282
# 11          3.698875           16.418115            34.729179
# 12          1.130375           29.955947           111.925383
# 13          0.573250            6.864007           241.241685
# 14          2.000000           48.100294            21.508004
# 15          1.597250           16.280526            63.849765
# 16          5.085625            8.809691            15.067369
# 17          3.278250           18.834966            17.152921
# 18          0.967000           20.948502            87.462201
# 19          1.419125           51.029707            27.275827

# %%
tdTomato_df.head(20)
# Out:
#                                        structure_name  left_cell_count  \
# 0                      Primary visual area, layer 2/3              5.0
# 1   Retrosplenial area, lateral agranular part, la...              1.0
# 2          Retrosplenial area, dorsal part, layer 2/3              2.0
# 3                posteromedial visual area, layer 2/3              1.0
# 4            Retrosplenial area, dorsal part, layer 1              0.0
# 5              Tuberomammillary nucleus, ventral part              0.0
# 6         Primary somatosensory area, mouth, layer 6b              0.0
# 7                                    internal capsule              0.0
# 8         Principal sensory nucleus of the trigeminal              0.0
# 9         Primary somatosensory area, trunk, layer 6a              0.0
# 10  Superior colliculus, motor related, intermedia...              0.0
# 11                      Interfascicular nucleus raphe              0.0
# 12                                Parataenial nucleus              0.0
# 13  Superior colliculus, motor related, intermedia...              0.0
# 14                                   Induseum griseum              0.0
# 15             Entorhinal area, lateral part, layer 2              0.0
# 16                            Anterior amygdalar area              0.0
# 17  Superior colliculus, motor related, deep gray ...              0.0
# 18  Intergeniculate leaflet of the lateral genicul...              0.0
# 19            Entorhinal area, lateral part, layer 6a              0.0
#
#     right_cell_count  total_cells  left_volume_mm3  right_volume_mm3  \
# 0               12.0         17.0         1.117625          1.094000
# 1               11.0         12.0         0.366750          0.353875
# 2                4.0          6.0         0.515875          0.511125
# 3                5.0          6.0         0.160125          0.157875
# 4                5.0          5.0         0.432375          0.427250
# 5                0.0          0.0         0.064875          0.062000
# 6                0.0          0.0         0.059375          0.059625
# 7                0.0          0.0         1.207875          1.195125
# 8                0.0          0.0         0.481000          0.493000
# 9                0.0          0.0         0.117500          0.116375
# 10               0.0          0.0         1.074625          1.023250
# 11               0.0          0.0         0.036125          0.047125
# 12               0.0          0.0         0.133000          0.132125
# 13               0.0          0.0         1.054625          1.039000
# 14               0.0          0.0         0.056000          0.081875
# 15               0.0          0.0         0.909125          0.903625
# 16               0.0          0.0         0.278000          0.278250
# 17               0.0          0.0         0.585875          0.575875
# 18               0.0          0.0         0.038875          0.036125
# 19               0.0          0.0         0.592250          0.592875
#
#     total_volume_mm3  left_cells_per_mm3  right_cells_per_mm3
# 0           2.211625            4.473773            10.968921
# 1           0.720625            2.726653            31.084422
# 2           1.027000            3.876908             7.825874
# 3           0.318000            6.245121            31.670625
# 4           0.859625            0.000000            11.702750
# 5           0.126875            0.000000             0.000000
# 6           0.119000            0.000000             0.000000
# 7           2.403000            0.000000             0.000000
# 8           0.974000            0.000000             0.000000
# 9           0.233875            0.000000             0.000000
# 10          2.097875            0.000000             0.000000
# 11          0.083250            0.000000             0.000000
# 12          0.265125            0.000000             0.000000
# 13          2.093625            0.000000             0.000000
# 14          0.137875            0.000000             0.000000
# 15          1.812750            0.000000             0.000000
# 16          0.556250            0.000000             0.000000
# 17          1.161750            0.000000             0.000000
# 18          0.075000            0.000000             0.000000
# 19          1.185125            0.000000             0.000000

# %%
labled_cells_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mc/qbcjsrl16h3gf6t6xvz8czzw0000gn/T/ipykernel_2919/1504546251.py in <module>
# ----> 1 labled_cells_df
#
# NameError: name 'labled_cells_df' is not defined

# %%
summary_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mc/qbcjsrl16h3gf6t6xvz8czzw0000gn/T/ipykernel_71449/1328616635.py in <module>
# ----> 1 summary_df
#
# NameError: name 'summary_df' is not defined

# %% [markdown]
# # Cellfinders inital outputs

# %%
gfp_df
# Out:
#                                         structure_name  left_cell_count  \
# 0                         Primary visual area, layer 5           2686.0
# 1             Retrosplenial area, dorsal part, layer 5           1346.0
# 2                         Primary visual area, layer 4            647.0
# 3                   posteromedial visual area, layer 5           1122.0
# 4    Retrosplenial area, lateral agranular part, la...           1002.0
# ..                                                 ...              ...
# 663              Interpeduncular nucleus, intermediate              0.0
# 664               Interpeduncular nucleus, dorsomedial              0.0
# 665              Interpeduncular nucleus, dorsolateral              0.0
# 666             Interpeduncular nucleus, rostrolateral              0.0
# 667                Supraoculomotor periaqueductal gray              0.0
#
#      right_cell_count  total_cells  left_volume_mm3  right_volume_mm3  \
# 0              6761.0       9447.0         0.868750          0.855750
# 1              2328.0       3674.0         0.644750          0.626500
# 2              2409.0       3056.0         0.567500          0.562875
# 3              1673.0       2795.0         0.159250          0.152125
# 4              1736.0       2738.0         0.400125          0.388375
# ..                ...          ...              ...               ...
# 663               0.0          0.0         0.016375          0.017250
# 664               0.0          0.0         0.008625          0.009375
# 665               0.0          0.0         0.018000          0.019625
# 666               0.0          0.0         0.009000          0.011125
# 667               0.0          0.0         0.019500          0.018875
#
#      total_volume_mm3  left_cells_per_mm3  right_cells_per_mm3
# 0            1.724500         3091.798561          7900.671925
# 1            1.271250         2087.630865          3715.881883
# 2            1.130375         1140.088106          4279.813458
# 3            0.311375         7045.525903         10997.534922
# 4            0.788500         2504.217432          4469.906662
# ..                ...                 ...                  ...
# 663          0.033625            0.000000             0.000000
# 664          0.018000            0.000000             0.000000
# 665          0.037625            0.000000             0.000000
# 666          0.020125            0.000000             0.000000
# 667          0.038375            0.000000             0.000000
#
# [668 rows x 9 columns]

# %%
tdTomato_df
# Out:
#      Unnamed: 0                                     structure_name  \
# 0             0                                 Olfactory tubercle
# 1             1                                      Piriform area
# 2             2           Retrosplenial area, dorsal part, layer 1
# 3             3         Retrosplenial area, dorsal part, layer 2/3
# 4             4  Retrosplenial area, lateral agranular part, la...
# ..          ...                                                ...
# 663         663              Interpeduncular nucleus, intermediate
# 664         664               Interpeduncular nucleus, dorsomedial
# 665         665              Interpeduncular nucleus, dorsolateral
# 666         666             Interpeduncular nucleus, rostrolateral
# 667         667                Supraoculomotor periaqueductal gray
#
#      left_cell_count  right_cell_count  total_cells  left_volume_mm3  \
# 0             6771.0            5166.0        50706         2.488875
# 1             5348.0            5904.0         1188         7.430750
# 2             2026.0            1420.0        16233         0.536000
# 3             1575.0            1281.0         9762         0.649250
# 4             1413.0             929.0        84720         0.333000
# ..               ...               ...          ...              ...
# 663              0.0               0.0        25648         0.025500
# 664              0.0               0.0        37459         0.013125
# 665              0.0               0.0        56380         0.025250
# 666              0.0               0.0        88194         0.011250
# 667              0.0               0.0        75532         0.028625
#
#      right_volume_mm3  total_volume_mm3  left_cells_per_mm3  \
# 0            2.452250          4.941125         2720.506253
# 1            7.541750         14.972500          719.712008
# 2            0.553500          1.089500         3779.850746
# 3            0.642625          1.291875         2425.876011
# 4            0.330250          0.663250         4243.243243
# ..                ...               ...                 ...
# 663          0.022750          0.048250            0.000000
# 664          0.011875          0.025000            0.000000
# 665          0.025625          0.050875            0.000000
# 666          0.012000          0.023250            0.000000
# 667          0.026125          0.054750            0.000000
#
#      right_cells_per_mm3
# 0            2106.636762
# 1             782.842179
# 2            2565.492322
# 3            1993.386501
# 4            2813.020439
# ..                   ...
# 663             0.000000
# 664             0.000000
# 665             0.000000
# 666             0.000000
# 667             0.000000
#
# [668 rows x 10 columns]

# %%
summary_df_0
# Out:
#                                         structure_name  left_cell_count  \
# 0                                   Olfactory tubercle           6771.0
# 1                                        Piriform area           5348.0
# 2             Retrosplenial area, dorsal part, layer 1           2026.0
# 3           Retrosplenial area, dorsal part, layer 2/3           1575.0
# 4    Retrosplenial area, lateral agranular part, la...           1413.0
# ..                                                 ...              ...
# 663              Interpeduncular nucleus, intermediate              0.0
# 664               Interpeduncular nucleus, dorsomedial              0.0
# 665              Interpeduncular nucleus, dorsolateral              0.0
# 666             Interpeduncular nucleus, rostrolateral              0.0
# 667                Supraoculomotor periaqueductal gray              0.0
#
#      right_cell_count  total_cells  left_volume_mm3  right_volume_mm3  \
# 0              5166.0      11937.0         2.488875          2.452250
# 1              5904.0      11252.0         7.430750          7.541750
# 2              1420.0       3446.0         0.536000          0.553500
# 3              1281.0       2856.0         0.649250          0.642625
# 4               929.0       2342.0         0.333000          0.330250
# ..                ...          ...              ...               ...
# 663               0.0          0.0         0.025500          0.022750
# 664               0.0          0.0         0.013125          0.011875
# 665               0.0          0.0         0.025250          0.025625
# 666               0.0          0.0         0.011250          0.012000
# 667               0.0          0.0         0.028625          0.026125
#
#      total_volume_mm3  left_cells_per_mm3  right_cells_per_mm3
# 0            4.941125         2720.506253          2106.636762
# 1           14.972500          719.712008           782.842179
# 2            1.089500         3779.850746          2565.492322
# 3            1.291875         2425.876011          1993.386501
# 4            0.663250         4243.243243          2813.020439
# ..                ...                 ...                  ...
# 663          0.048250            0.000000             0.000000
# 664          0.025000            0.000000             0.000000
# 665          0.050875            0.000000             0.000000
# 666          0.023250            0.000000             0.000000
# 667          0.054750            0.000000             0.000000
#
# [668 rows x 9 columns]
